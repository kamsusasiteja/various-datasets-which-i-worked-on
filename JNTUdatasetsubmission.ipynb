# %%
import os

# %%
os.chdir("C:/Users/User/Desktop/datasets")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
jntu=pd.read_csv("JNTU Sample data.csv")
jntu
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
jntu.head()
# Out:
#        State Division        Region        Branch Route Code     Village Name  \
# 0  Karnataka    KA 02  GOWRIBIDANUR  Gowribidanur   KGAWGAWD  Ramachandrapura
# 1  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC   sadapana halli
# 2  Karnataka    KA 01   VIJAYAPURAM   Vijaypura-2   KVIJVIBC        yanagante
# 3  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC        yanagante
# 4  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC       sathyavara
#
#    pincode        Center Name  Group Name                  Name  Loan nature  \
# 0   504273    Ramachandrapura        Rama       Vadand Geetaben            1
# 1   504293  sadapanahalli new  sumithra 1   Co Patel Manjulaben            1
# 2   504307          yanagante  lakshmamma     Ghanchi Aminabibi            1
# 3   504001          yanagante     fincare  Ghanchi Farajanabanu            1
# 4   504001         sathyavara     saibaba  Ghanchee Shabanabanu            1
#
# ...

# %%
jntu.describe()
# Out:
#              pincode   Loan nature  Existing Loan amount            AGE  \
# count   13435.000000  13435.000000           13435.000000  13435.000000
# mean   514413.112467      1.004838          119970.319762     33.101005
# std      8956.411939      0.069391           63417.170414      8.913726
# min    500001.000000      1.000000           10055.000000     18.000000
# 25%    506313.000000      1.000000           64990.000000     25.000000
# 50%    515832.000000      1.000000          120668.000000     33.000000
# 75%    521402.000000      1.000000          174660.500000     41.000000
# max    534475.000000      2.000000          229988.000000     48.000000
#
#        ADHAAR NUMBER
# count   1.343500e+04
# mean    5.563284e+15
# std     2.487175e+15
# min     1.250000e+15
# 25%     3.420000e+15
# 50%     5.550000e+15
# 75%     7.710000e+15
# max     9.870000e+15

# %%
corr=jntu.corr()

# %%
corr
# Out:
#                         pincode  Loan nature  Existing Loan amount        AGE  \
# pincode                1.000000    -0.007323              -0.002371 -0.012817
# Loan nature           -0.007323     1.000000               0.018842 -0.006085
# Existing Loan amount  -0.002371     0.018842               1.000000  0.003833
# AGE                   -0.012817    -0.006085               0.003833  1.000000
# ADHAAR NUMBER          0.009718     0.002008               0.019435 -0.003468
#
#                        ADHAAR NUMBER
# pincode                     0.009718
# Loan nature                 0.002008
# Existing Loan amount        0.019435
# AGE                        -0.003468
# ADHAAR NUMBER               1.000000

# %%
jntu.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                          0
# Division                       0
# Region                         0
# Branch                         1
# Route Code                     0
# Village Name                   0
# pincode                        0
# Center Name                    0
# Group Name                     0
# Name                           0
# Loan nature                    0
# Employee Name for clinet       0
# Existing Loan amount           0
# Loan Date                      0
# AGE                            0
# ID_DETAILS                     0
# ADHAAR NUMBER                  0
# Marital_Status                 0
# INCOME SOURCE               3435
# LoanStatus                  4941
# dtype: int64

# %%
features=jntu.iloc[:,[18,19]].values
features
# Out:
# array([['BUSINESS', 'NO'],
#        ['AGRICULTURE', 'YES'],
#        ['AGRICULTURE', 'YES'],
#        ...,
#        [nan, nan],
#        [nan, nan],
#        [nan, nan]], dtype=object)

# %%
from sklearn.preprocessing import Imputer
imp=Imputer(missing_values="NaN",strategy="most_frequent",axis=0)
imp
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='most_frequent',
#     verbose=0)

# %%
imp.fit(features[:,[18,19]])
features[:,[18,19]]=imp.fit_transform(features[:,[18,19]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-83b4ec0a177a> in <module>
# ----> 1 imp.fit(features[:,[18,19]])
#       2 features[:,[18,19]]=imp.fit_transform(features[:,[18,19]])
#
# IndexError: index 18 is out of bounds for axis 1 with size 2

# %%
jntu["LoanStatus"].value_counts()
# Out:
# YES    5965
# NO     2529
# Name: LoanStatus, dtype: int64

# %%
jntu["LoanStatus"].fillna("YES",inplace=True)

# %%
jntu
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
jntu["INCOME SOURCE"].value_counts()
# Out:
# BUSINESS         3023
# AGRICULTURE      2790
# OTHER            1963
# DAIRY            1016
# FLOWER SELLER    1004
# LAND              204
# Name: INCOME SOURCE, dtype: int64

# %%
jntu["INCOME SOURCE"].fillna("BUSINESS",inplace=True)

# %%
jntu
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
jntu["LoanStatus"]=labelencoder.fit_transform(jntu["LoanStatus"])
jntu
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
jntu["Marital_Status"]=labelencoder.fit_transform(jntu["Marital_Status"])
jntu
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %% [markdown]
# # linear regression

# %%
X=jntu['pincode']
Y=jntu['LoanStatus']

# %%
import statsmodels.api as sm

# %%
model1=sm.OLS(Y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             LoanStatus   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                 5.841e+04
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):               0.00
# Time:                        21:35:21   Log-Likelihood:                -6399.5
# No. Observations:               13435   AIC:                         1.280e+04
# Df Residuals:                   13434   BIC:                         1.281e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pincode     1.579e-06   6.53e-09    241.675      0.000    1.57e-06    1.59e-06
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=1)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
result=model.fit(X_train,Y_train)
result
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy=model.score(X_train,Y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.011942555127468224

# %% [markdown]
# # logistic regression

# %%
jntu["Marital_Status"].value_counts()
# Out:
# 1    11998
# 2     1338
# 3       73
# 0       26
# Name: Marital_Status, dtype: int64
