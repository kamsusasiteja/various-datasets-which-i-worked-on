# %%
import os

# %%
os.chdir("C:/Users/User/Desktop/datasets")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data=pd.read_csv('16Super_Store.csv',header=0,encoding='unicode_escape')
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 3          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 4         11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 5         24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 6         25  CA-2015-106320   9/25/2015   9/30/2015  Standard Class
# 7         28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 8         30  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 9         37  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 10        39  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 11        40  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 12        52  CA-2015-115742   4/18/2015   4/22/2015  Standard Class
# ...

# %%
data.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
corr=data.corr()

# %%
corr
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.017164  0.001696 -0.000246  0.031848  0.008775
# Postal Code  0.017164     1.000000 -0.011786  0.013700  0.106736 -0.026335
# Sales        0.001696    -0.011786  1.000000  0.437464 -0.028576  0.173510
# Quantity    -0.000246     0.013700  0.437464  1.000000 -0.015695  0.061213
# Discount     0.031848     0.106736 -0.028576 -0.015695  1.000000 -0.483769
# Profit       0.008775    -0.026335  0.173510  0.061213 -0.483769  1.000000

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# row id,postal code,Quantity are int.... Sales Discount and profit are float values...so basically, we"ll go with regression.

# %%
data.pivot_table(data,index=['Discount'])
# Out:
#            Postal Code      Profit  Quantity       Row ID       Sales
# Discount
# 0.00      52701.443780   69.537173  3.856459  4986.083732  306.250323
# 0.10      10459.618421   93.565946  4.118421  5431.447368  613.608513
# 0.15      92498.192308   27.288298  3.807692  4968.923077  529.971567
# 0.20      61944.076423   10.188535  3.635772  4868.060163  352.245554
# 0.30      54186.202703  -48.177103  3.770270  5413.418919  448.064640
# 0.32      76826.148148  -88.560656  3.888889  5334.814815  536.794770
# 0.40      24147.373333 -215.831957  3.893333  5021.680000  608.192080
# 0.45      32965.000000 -226.646464  4.090909  3876.090909  498.634000
# 0.50      59436.185185 -238.355537  3.870370  4671.370370  388.582778
# 0.60      70142.014493  -43.077212  3.630435  5509.355072   48.150000
# 0.70      84714.133333 -259.662627  4.533333  5486.800000  163.958800

# %%
data.pivot_table(data,index=['Quantity'])
# Out:
#           Discount   Postal Code      Profit       Row ID        Sales
# Quantity
# 1         0.179845  53972.062176   -0.547125  4904.943005    95.809531
# 2         0.170915  53349.061630    4.632534  4991.759443   174.239542
# 3         0.171854  57049.889513    5.482997  5088.518727   258.337421
# 4         0.162065  55782.781377    7.911537  5179.101215   344.456398
# 5         0.200356  58475.924901   12.491970  5166.596838   504.507713
# 6         0.176612  58100.495868   14.469486  5050.479339   611.026359
# 7         0.190957  56733.356522  -21.730520  4825.434783   607.494069
# 8         0.143103  57981.051724   62.164510  4754.431034   753.269103
# 9         0.161552  52786.103448   60.457484  4919.413793   952.669071
# 10        0.155833  46454.500000   64.363083  6373.416667  1119.806167
# 11        0.050000  45486.375000  209.349662  4588.500000   879.410125
# 12        0.200000  67855.500000  -57.833200  4936.166667  1463.808000
# ...

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    1248
# Second Class       427
# First Class        327
# Same Day           119
# Name: Ship Mode, dtype: int64

# %%
data['Row ID'].value_counts()
# Out:
# 6139    1
# 7537    1
# 9566    1
# 5472    1
# 5474    1
# 3427    1
# 9327    1
# 3429    1
# 1382    1
# 5113    1
# 9576    1
# 1386    1
# 3437    1
# 9582    1
# 3439    1
# 9584    1
# 1396    1
# 5361    1
# 7541    1
# 7543    1
# 9592    1
# 4474    1
# 8392    1
# 1406    1
# 8305    1
# 1410    1
# 7555    1
# 1412    1
# 1416    1
# 7561    1
#        ..
# 4685    1
# 5466    1
# 6208    1
# 8119    1
# 2646    1
# 4697    1
# 4699    1
# 5149    1
# 4703    1
# 4707    1
# 2660    1
# 8807    1
# 617     1
# 6762    1
# 621     1
# 6766    1
# 623     1
# 2672    1
# 627     1
# 7563    1
# 6780    1
# 639     1
# 641     1
# 8550    1
# 6788    1
# 2694    1
# 6792    1
# 649     1
# 7390    1
# 8192    1
# Name: Row ID, Length: 2121, dtype: int64

# %%
data['Customer Name'].value_counts()
# Out:
# Seth Vernon          15
# Lena Creighton        9
# Caroline Jumper       9
# Kelly Lampkin         9
# Joel Eaton            9
# John Lee              8
# Laura Armstrong       8
# Arthur Gainer         8
# Anne McFarland        8
# Anna Andreadi         8
# Zuschuss Carroll      8
# Mike Pelletier        8
# Sanjit Chand          8
# Paul Prost            8
# George Bell           8
# Justin Deggeller      8
# Keith Dawkins         7
# Beth Paige            7
# Joe Elijah            7
# Noel Staavos          7
# Logan Currie          7
# Harry Marie           7
# Sean O'Donnell        7
# Gary McGarr           7
# Jane Waco             7
# Carlos Soltero        7
# Mick Crebagga         7
# Lena Cacioppo         7
# Rick Bensley          7
# David Smith           7
#                      ..
# Thomas Boland         1
# Evan Minnotte         1
# Stuart Van            1
# Fred Harton           1
# Steve Carroll         1
# Alyssa Crouse         1
# Kristina Nunn         1
# ...

# %%
data['Segment'].value_counts()
# Out:
# Consumer       1113
# Corporate       646
# Home Office     362
# Name: Segment, dtype: int64

# %%
data['Country'].value_counts()
# Out:
# United States    2121
# Name: Country, dtype: int64

# %%
data['City'].value_counts()
# Out:
# New York City       192
# Los Angeles         154
# Philadelphia        111
# San Francisco       102
# Seattle              97
# Houston              81
# Chicago              68
# Columbus             48
# San Diego            46
# Detroit              28
# Dallas               27
# Springfield          27
# Jacksonville         24
# Aurora               21
# Columbia             18
# Newark               18
# Milwaukee            16
# Louisville           16
# Richmond             16
# Henderson            15
# Phoenix              14
# Jackson              13
# Franklin             13
# Arlington            13
# Oceanside            13
# Lakewood             13
# San Antonio          12
# Pasadena             11
# Baltimore            11
# Tampa                11
#                    ...
# Bangor                1
# Allentown             1
# Daytona Beach         1
# Moorhead              1
# Santa Barbara         1
# Warner Robins         1
# Fremont               1
# ...

# %%
data['Category'].value_counts()
# Out:
# Furniture    2121
# Name: Category, dtype: int64

# %%
data['Sub-Category'].value_counts()
# Out:
# Furnishings    957
# Chairs         617
# Tables         319
# Bookcases      228
# Name: Sub-Category, dtype: int64

# %%
data['Discount'].value_counts()
# Out:
# 0.00    836
# 0.20    615
# 0.30    222
# 0.60    138
# 0.10     76
# 0.40     75
# 0.50     54
# 0.15     52
# 0.32     27
# 0.70     15
# 0.45     11
# Name: Discount, dtype: int64

# %%
furn=data[data['Sub-Category'].str.contains('Furnishings')]
furn
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8         30  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 9         37  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 12        52  CA-2015-115742   4/18/2015   4/22/2015  Standard Class
# 15        66  CA-2015-135545  11/24/2015  11/30/2015  Standard Class
# 18        74  US-2015-134026   4/26/2015    5/2/2015  Standard Class
# 19        77  US-2017-118038   12/9/2017  12/11/2017     First Class
# 20        79  US-2014-147606  11/26/2014   12/1/2014    Second Class
# 22        94  CA-2015-149587   1/31/2015    2/5/2015    Second Class
# 23        97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 24       105  US-2015-156867  11/13/2015  11/17/2015  Standard Class
# 25       111  CA-2017-146780  12/25/2017  12/30/2017  Standard Class
# 27       120  CA-2016-103730   6/12/2016   6/15/2016     First Class
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
data['Sales'].hist(bins=10)

# %%
data['Discount'].hist(bins=10)

# %%
data['Profit'].hist(bins=10)

# %%
data.boxplot(column='Sales')

# %%
data.boxplot(column='Sales',by='Discount')

# %%
data.boxplot(column='Sales',by='Profit')
