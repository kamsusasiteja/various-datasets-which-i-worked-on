# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User'

# %%
os.chdir("C:/Users/User/Desktop/datasets")

# %%
import numpy as np
import pandas as pd
data1=pd.read_csv("turnover.csv")

# %%
data1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
data1.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
data1.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# ...

# %%
data1.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
data1.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
data1['salary']
# Out:
# 0           low
# 1        medium
# 2        medium
# 3           low
# 4           low
# 5           low
# 6           low
# 7           low
# 8           low
# 9           low
# 10          low
# 11          low
# 12          low
# 13          low
# 14          low
# 15          low
# 16          low
# 17          low
# 18          low
# 19          low
# 20          low
# 21          low
# 22          low
# 23          low
# 24          low
# 25          low
# 26          low
# 27          low
# 28          low
# 29          low
#           ...
# 14969    medium
# 14970    medium
# 14971    medium
# 14972    medium
# 14973    medium
# 14974    medium
# 14975    medium
# 14976    medium
# 14977    medium
# 14978    medium
# 14979    medium
# 14980      high
# 14981       low
# 14982    medium
# 14983    medium
# 14984    medium
# 14985    medium
# 14986       low
# 14987       low
# 14988       low
# 14989       low
# 14990       low
# 14991       low
# 14992       low
# ...

# %%
data1[0:10]
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# ...

# %%
mean_avg_hours=data1['average_montly_hours'].mean()

# %%
mean_avg_hours
# Out:
# 201.0503366891126

# %%
data1.shape
# Out:
# (14999, 10)

# %%
data1.pivot_table(data1,index=['number_project'])
# Out:
#                 Work_accident  average_montly_hours  last_evaluation  \
# number_project
# 2                    0.092965            160.342546         0.568505
# 3                    0.175092            197.507522         0.716572
# 4                    0.156472            205.122108         0.740009
# 5                    0.150670            212.061572         0.762010
# 6                    0.114140            238.694208         0.786550
# 7                    0.015625            276.078125         0.859609
#
#                     left  promotion_last_5years  satisfaction_level  \
# number_project
# 2               0.656198               0.015494            0.478769
# 3               0.017756               0.023428            0.687670
# 4               0.093700               0.026804            0.695132
# 5               0.221659               0.018109            0.678888
# 6               0.557922               0.017036            0.273458
# ...

# %%
data1['number_project'].value_counts()
# Out:
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64

# %%
data1.pivot_table(data1,index=['time_spend_company'])
# Out:
#                     Work_accident  average_montly_hours  last_evaluation  \
# time_spend_company
# 2                        0.172010            200.133169         0.717596
# 3                        0.138910            186.632935         0.668721
# 4                        0.124364            223.455221         0.767927
# 5                        0.116090            222.978955         0.813666
# 6                        0.149025            212.051532         0.754875
# 7                        0.138298            200.744681         0.682766
# 8                        0.271605            193.802469         0.711975
# 10                       0.233645            199.224299         0.731495
#
#                         left  number_project  promotion_last_5years  \
# time_spend_company
# 2                   0.016338        3.687423               0.016646
# 3                   0.246159        3.327798               0.020798
# ...

# %%
data1['time_spend_company'].value_counts()
# Out:
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: time_spend_company, dtype: int64

# %%
data1.pivot_table(data1,index=['sales'])
# Out:
#              Work_accident  average_montly_hours  last_evaluation      left  \
# sales
# IT                0.133659            202.215974         0.716830  0.222494
# RandD             0.170267            200.800508         0.712122  0.153748
# accounting        0.125163            201.162973         0.717718  0.265971
# hr                0.120433            198.684709         0.708850  0.290934
# management        0.163492            201.249206         0.724000  0.144444
# marketing         0.160839            199.385781         0.715886  0.236597
# product_mng       0.146341            199.965632         0.714756  0.219512
# sales             0.141787            200.911353         0.709717  0.244928
# support           0.154778            200.758188         0.723109  0.248991
# technical         0.140074            202.497426         0.721099  0.256250
#
#              number_project  promotion_last_5years  satisfaction_level  \
# sales
# ...

# %%
data1['sales'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
emp_detail=data1[data1['sales'].str.contains('technical')]

# %%
emp_detail
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 35                   0.10             0.94               6
# 36                   0.38             0.46               2
# 37                   0.45             0.50               2
# 38                   0.11             0.89               6
# 39                   0.41             0.54               2
# 40                   0.87             0.88               5
# 41                   0.45             0.48               2
# 42                   0.40             0.46               2
# 43                   0.10             0.80               7
# 44                   0.09             0.89               6
# 45                   0.84             0.74               3
# 57                   0.10             0.81               6
# 58                   0.38             0.54               2
# 59                   0.85             1.00               4
# 81                   0.38             0.49               2
# ...

# %%
emp_data=data1[data1['sales'].str.contains('technical') & data1['salary'].str.contains('medium')]

# %%
emp_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 113                  0.90             0.96               4
# 114                  0.84             1.00               5
# 115                  0.37             0.48               2
# 116                  0.86             0.68               5
# 188                  0.37             0.55               2
# 191                  0.92             0.87               4
# 192                  0.74             0.91               4
# 193                  0.09             0.82               6
# 194                  0.89             0.95               4
# 265                  0.84             0.93               4
# 266                  0.11             0.95               6
# 269                  0.38             0.86               6
# 270                  0.44             0.51               2
# 271                  0.11             0.84               6
# 272                  0.81             0.93               5
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
data1['satisfaction_level'].hist(bins=10)

# %%
data1.boxplot(column='number_project',by='time_spend_company')

# %%
data1.boxplot(column='satisfaction_level',by='time_spend_company')

# %%
data1.boxplot(column='satisfaction_level',by='number_project')

# %%
data1.boxplot(column='time_spend_company',by='salary')

# %%
data1.boxplot(column='time_spend_company',by='left')

# %%
data1.boxplot(column='left',by='time_spend_company')

# %%
data1.boxplot(column='satisfaction_level')

# %%
data1.boxplot(column='number_project')

# %%
data1.boxplot(column='Work_accident')
